# %% [markdown]
# # Load anndata object (scrnaseq)

# %%
import anndata as ad
import spatialdata as sd
import scanpy as sc
import numpy as np

# %% [markdown]
# We read the scRNAseq data. We use scanpy for this

# %%
adata=sc.read('../../../data/scrnaseq/hlca_core_subsample_10perc.h5ad')

# %% [markdown]
# We want to want to explore the adata object. As you can see, we have a lot of donors and technolgoies, since it's an integrated version. **Please consider this in subsequent analysis**

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 58494 × 27957
# ...

# %% [markdown]
# We for example we can select cells from a single donor

# %%
adata_donor=adata[adata.obs['donor_id']==np.unique(adata.obs['donor_id'])[15]]

# %% [markdown]
# As you can see in the assay column below, this corresponds to cells from 10x 3' v2 chromium.

# %%
adata_donor.obs
# Out:
#                                      suspension_type  \
# AACCATGGTGAAGGCT-1-HCATisStab7747200            cell
# AACTCCCTCAACGCTA-1-HCATisStab7747200            cell
# CTTAGGAGTTAAGGGC-1-HCATisStab7747200            cell
# GCGCGATGTCACACGC-1-HCATisStab7747198            cell
# AGAGTGGGTGATGCCC-1-HCATisStab7747200            cell
# ...                                              ...
# GCTGCAGAGACCGGAT-1-HCATisStab7747200            cell
# AGGTCCGAGGCTCTTA-1-HCATisStab7747200            cell
# CACAGTATCCCTGACT-1-HCATisStab7747198            cell
# CTCAGAAGTTTAAGCC-1-HCATisStab7747199            cell
# CATGGCGAGCTCAACT-1-HCATisStab7747198            cell
#
#                                                                                donor_id  \
# AACCATGGTGAAGGCT-1-HCATisStab7747200  homosapiens_None_2023_None_sikkemalisa_001_d10...
# AACTCCCTCAACGCTA-1-HCATisStab7747200  homosapiens_None_2023_None_sikkemalisa_001_d10...
# ...

# %% [markdown]
# Important: the counts in .X are transformed. Please use the 'raw' counts contained in the object for quantifying distributions.

# %%
adata_donor.raw.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 2057401 stored elements and shape (1399, 27957)>
